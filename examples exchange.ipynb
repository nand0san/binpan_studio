# %%
from IPython.display import display, HTML

display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from binpan import binpan
from binpan import handlers
import pandas as pd

# %% [markdown]
# # Exchange examples

# %%
ex = binpan.Exchange()

# %% [markdown]
# # Main dataframe with symbols info

# %%
ex.df
# Out:
#           status baseAsset  baseAssetPrecision quoteAsset  quotePrecision  quoteAssetPrecision  baseCommissionPrecision  quoteCommissionPrecision                                         orderTypes  icebergAllowed  ...  quoteOrderQtyMarketAllowed  \
# symbol                                                                                                                                                                                                                ...
# ETHBTC   TRADING       ETH                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# LTCBTC   TRADING       LTC                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# BNBBTC   TRADING       BNB                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# NEOBTC   TRADING       NEO                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# QTUMETH  TRADING      QTUM                   8        ETH               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# ...          ...       ...                 ...        ...             ...                  ...                      ...                       ...                                                ...             ...  ...                         ...
# BTCPLN   TRADING       BTC                   8        PLN               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# ETHPLN   TRADING       ETH                   8        PLN               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# BUSDPLN  TRADING      BUSD                   8        PLN               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# APTEUR   TRADING       APT                   8        EUR               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# APTTRY   TRADING       APT                   8        TRY               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
#
#          allowTrailingStop  cancelReplaceAllowed  isSpotTradingAllowed  isMarginTradingAllowed                                            filters  SPOT  MARGIN  TRD_GRP_004  TRD_GRP_005
# symbol
# ETHBTC                True                  True                  True                    True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  True    True         True         True
# LTCBTC                True                  True                  True                    True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  True    True         True         True
# BNBBTC                True                  True                  True                    True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  True    True         True         True
# NEOBTC                True                  True                  True                    True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  True    True         True        False
# QTUMETH               True                  True                  True                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  True    True        False        False
# ...                    ...                   ...                   ...                     ...                                                ...   ...     ...          ...          ...
# BTCPLN                True                  True                  True                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '1...  True   False        False        False
# ETHPLN                True                  True                  True                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '1...  True   False        False        False
# BUSDPLN               True                  True                  True                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  True   False        False        False
# APTEUR                True                  True                  True                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  True   False        False        False
# APTTRY                True                  True                  True                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  True   False        False        False
#
# [2115 rows x 21 columns]

# %% [markdown]
# ## Dataframe with order types by symbol

# %%
ex.order_types
# Out:
#          LIMIT  LIMIT_MAKER  MARKET  STOP_LOSS_LIMIT  TAKE_PROFIT_LIMIT
# symbol
# ETHBTC    True         True    True             True               True
# LTCBTC    True         True    True             True               True
# BNBBTC    True         True    True             True               True
# NEOBTC    True         True    True             True               True
# QTUMETH   True         True    True             True               True
# ...        ...          ...     ...              ...                ...
# BTCPLN    True         True    True             True               True
# ETHPLN    True         True    True             True               True
# BUSDPLN   True         True    True             True               True
# APTEUR    True         True    True             True               True
# APTTRY    True         True    True             True               True
#
# [2115 rows x 5 columns]

# %% [markdown]
# ## Any dataframe reponse can be applied pandas methods

# %%
ex.order_types[ex.order_types['MARKET'].isna()]
# Out:
# Empty DataFrame
# Columns: [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, TAKE_PROFIT_LIMIT]
# Index: []

# %% [markdown]
# ## Update the exchange info from API

# %%
pepe = ex.update_info()
pepe[list(pepe.keys())[0]]
# Out:
# {'symbol': 'ETHBTC',
#  'status': 'TRADING',
#  'baseAsset': 'ETH',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'BTC',
#  'quotePrecision': 8,
#  'quoteAssetPrecision': 8,
#  'baseCommissionPrecision': 8,
#  'quoteCommissionPrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'ocoAllowed': True,
#  'quoteOrderQtyMarketAllowed': True,
#  'allowTrailingStop': True,
#  'cancelReplaceAllowed': True,
#  'isSpotTradingAllowed': True,
#  'isMarginTradingAllowed': True,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.00000100',
#    'maxPrice': '922327.00000000',
#    'tickSize': '0.00000100'},
#   {'filterType': 'PERCENT_PRICE',
#    'multiplierUp': '5',
#    'multiplierDown': '0.2',
#    'avgPriceMins': 5},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.00010000',
#    'maxQty': '100000.00000000',
#    'stepSize': '0.00010000'},
#   {'filterType': 'MIN_NOTIONAL',
#    'minNotional': '0.00010000',
#    'applyToMarket': True,
#    'avgPriceMins': 5},
#   {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#   {'filterType': 'MARKET_LOT_SIZE',
#    'minQty': '0.00000000',
#    'maxQty': '1953.73391792',
#    'stepSize': '0.00000000'},
#   {'filterType': 'TRAILING_DELTA',
#    'minTrailingAboveDelta': 10,
#    'maxTrailingAboveDelta': 2000,
#    'minTrailingBelowDelta': 10,
#    'maxTrailingBelowDelta': 2000},
#   {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#   {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#  'permissions': ['SPOT', 'MARGIN', 'TRD_GRP_004', 'TRD_GRP_005']}

# %% [markdown]
# ## Symbol's info can be requested anytime without calling API again

# %%
infd = ex.info_dic
infd['ETHUSDT']
# Out:
# {'symbol': 'ETHUSDT',
#  'status': 'TRADING',
#  'baseAsset': 'ETH',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'USDT',
#  'quotePrecision': 8,
#  'quoteAssetPrecision': 8,
#  'baseCommissionPrecision': 8,
#  'quoteCommissionPrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'ocoAllowed': True,
#  'quoteOrderQtyMarketAllowed': True,
#  'allowTrailingStop': True,
#  'cancelReplaceAllowed': True,
#  'isSpotTradingAllowed': True,
#  'isMarginTradingAllowed': True,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.01000000',
#    'maxPrice': '1000000.00000000',
#    'tickSize': '0.01000000'},
#   {'filterType': 'PERCENT_PRICE',
#    'multiplierUp': '5',
#    'multiplierDown': '0.2',
#    'avgPriceMins': 5},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.00010000',
#    'maxQty': '9000.00000000',
#    'stepSize': '0.00010000'},
#   {'filterType': 'MIN_NOTIONAL',
#    'minNotional': '10.00000000',
#    'applyToMarket': True,
#    'avgPriceMins': 5},
#   {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#   {'filterType': 'MARKET_LOT_SIZE',
#    'minQty': '0.00000000',
#    'maxQty': '9222.00000000',
#    'stepSize': '0.00000000'},
#   {'filterType': 'TRAILING_DELTA',
#    'minTrailingAboveDelta': 10,
#    'maxTrailingAboveDelta': 2000,
#    'minTrailingBelowDelta': 10,
#    'maxTrailingBelowDelta': 2000},
#   {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#   {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#  'permissions': ['SPOT', 'MARGIN', 'TRD_GRP_004', 'TRD_GRP_005']}

# %% [markdown]
# # Some methods to obtain info about symbols, fees, coins, etc...

# %%
ex.filter('BTCUSDT')
# Out:
# {'PRICE_FILTER_minPrice': '0.01000000',
#  'PRICE_FILTER_maxPrice': '1000000.00000000',
#  'PRICE_FILTER_tickSize': '0.01000000',
#  'PERCENT_PRICE_multiplierUp': '5',
#  'PERCENT_PRICE_multiplierDown': '0.2',
#  'PERCENT_PRICE_avgPriceMins': 5,
#  'LOT_SIZE_minQty': '0.00001000',
#  'LOT_SIZE_maxQty': '9000.00000000',
#  'LOT_SIZE_stepSize': '0.00001000',
#  'MIN_NOTIONAL_minNotional': '10.00000000',
#  'MIN_NOTIONAL_applyToMarket': True,
#  'MIN_NOTIONAL_avgPriceMins': 5,
#  'ICEBERG_PARTS_limit': 10,
#  'MARKET_LOT_SIZE_minQty': '0.00000000',
#  'MARKET_LOT_SIZE_maxQty': '463.55247000',
#  'MARKET_LOT_SIZE_stepSize': '0.00000000',
#  'TRAILING_DELTA_minTrailingAboveDelta': 10,
#  'TRAILING_DELTA_maxTrailingAboveDelta': 2000,
#  'TRAILING_DELTA_minTrailingBelowDelta': 10,
#  'TRAILING_DELTA_maxTrailingBelowDelta': 2000,
#  'MAX_NUM_ORDERS_maxNumOrders': 200,
#  'MAX_NUM_ALGO_ORDERS_maxNumAlgoOrders': 5}

# %%
ex.fee('BTCUSDT')
# Out:
# makerCommission    0.0
# takerCommission    0.0
# Name: BTCUSDT, dtype: float64

# %%
ex.coin('BTC')
# Out:
# depositAllEnable        True
# withdrawAllEnable       True
# name                 Bitcoin
# free                     0.0
# locked                     0
# freeze                     0
# withdrawing                0
# ipoing                     0
# ipoable                    0
# storage                    0
# isLegalMoney           False
# trading                 True
# Name: BTC, dtype: object

# %% [markdown]
# ### Info about Binance blockchain networks for any coin

# %%
ex.network('BTC')
# Out:
#         network  withdrawIntegerMultiple  isDefault  depositEnable  withdrawEnable depositDesc                                       withdrawDesc                                        specialTips                                specialWithdrawTips  \
# coin
# BTC         ETH             1.000000e-08      False           True            True                                                                 This deposit address supports ERC20 BBTC token...  You are withdrawing Binance Wrapped BTC (BBTC)...
# BTC         BTC             1.000000e-08       True           True            True
# BTC         BNB             1.000000e-08      False           True            True                                                                 Please enter both MEMO and Address data, which...                                                NaN
# BTC         BSC             1.000000e-08      False           True            True                                                                                                                    The network you have selected is BSC. Please e...
# BTC   SEGWITBTC             1.000000e-08      False           True           False              We have disabled withdrawals as our systems ar...
#
#                          name  ...  withdrawFee withdrawMin   withdrawMax minConfirm  unLockConfirm  sameAddress  estimatedArrivalTime   busy                 country  depositDust
# coin                           ...
# BTC          Ethereum (ERC20)  ...     0.000160    0.000320  1.000000e+10         12              0        False                     5  False  AE,BINANCE_BAHRAIN_BSC          NaN
# BTC                   Bitcoin  ...     0.000200    0.001000  7.500000e+03          1              2        False                    60  False  AE,BINANCE_BAHRAIN_BSC          NaN
# BTC   BNB Beacon Chain (BEP2)  ...     0.000007    0.000014  1.000000e+10          1              0         True                     5  False  AE,BINANCE_BAHRAIN_BSC          NaN
# BTC   BNB Smart Chain (BEP20)  ...     0.000004    0.000008  1.000000e+10         15              0        False                     5  False  AE,BINANCE_BAHRAIN_BSC          NaN
# BTC               BTC(SegWit)  ...     0.000500    0.001000  1.000000e+10          1              2        False                     5  False                     NaN          NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Filter symbols with a coin as base or quote or both.

# %%
l = ex.get_symbols('BTC', base=False, quote=True)
l[:15]
# Out:
# ['ETHBTC',
#  'LTCBTC',
#  'BNBBTC',
#  'NEOBTC',
#  'BCCBTC',
#  'GASBTC',
#  'HSRBTC',
#  'MCOBTC',
#  'WTCBTC',
#  'LRCBTC',
#  'QTUMBTC',
#  'YOYOBTC',
#  'OMGBTC',
#  'ZRXBTC',
#  'STRATBTC']

# %% [markdown]
# ## Other method to show the symbols dataframe

# %%
ex.get_df()
# Out:
#           status baseAsset  baseAssetPrecision quoteAsset  quotePrecision  quoteAssetPrecision  baseCommissionPrecision  quoteCommissionPrecision                                         orderTypes  icebergAllowed  ...  quoteOrderQtyMarketAllowed  \
# symbol                                                                                                                                                                                                                ...
# ETHBTC   TRADING       ETH                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# LTCBTC   TRADING       LTC                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# BNBBTC   TRADING       BNB                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# NEOBTC   TRADING       NEO                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# QTUMETH  TRADING      QTUM                   8        ETH               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# ...          ...       ...                 ...        ...             ...                  ...                      ...                       ...                                                ...             ...  ...                         ...
# BTCPLN   TRADING       BTC                   8        PLN               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# ETHPLN   TRADING       ETH                   8        PLN               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# BUSDPLN  TRADING      BUSD                   8        PLN               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# APTEUR   TRADING       APT                   8        EUR               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
# APTTRY   TRADING       APT                   8        TRY               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                        True
#
#          allowTrailingStop  cancelReplaceAllowed  isSpotTradingAllowed  isMarginTradingAllowed                                            filters  SPOT  MARGIN  TRD_GRP_004  TRD_GRP_005
# symbol
# ETHBTC                True                  True                  True                    True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  True    True         True         True
# LTCBTC                True                  True                  True                    True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  True    True         True         True
# BNBBTC                True                  True                  True                    True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  True    True         True         True
# NEOBTC                True                  True                  True                    True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  True    True         True        False
# QTUMETH               True                  True                  True                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  True    True        False        False
# ...                    ...                   ...                   ...                     ...                                                ...   ...     ...          ...          ...
# BTCPLN                True                  True                  True                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '1...  True   False        False        False
# ETHPLN                True                  True                  True                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '1...  True   False        False        False
# BUSDPLN               True                  True                  True                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  True   False        False        False
# APTEUR                True                  True                  True                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  True   False        False        False
# APTTRY                True                  True                  True                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  True   False        False        False
#
# [2115 rows x 21 columns]

# %% [markdown]
# ## Order types supported by symbols

# %%
ex.get_order_types()
# Out:
#          LIMIT  LIMIT_MAKER  MARKET  STOP_LOSS_LIMIT  TAKE_PROFIT_LIMIT
# symbol
# ETHBTC    True         True    True             True               True
# LTCBTC    True         True    True             True               True
# BNBBTC    True         True    True             True               True
# NEOBTC    True         True    True             True               True
# QTUMETH   True         True    True             True               True
# ...        ...          ...     ...              ...                ...
# BTCPLN    True         True    True             True               True
# ETHPLN    True         True    True             True               True
# BUSDPLN   True         True    True             True               True
# APTEUR    True         True    True             True               True
# APTTRY    True         True    True             True               True
#
# [2115 rows x 5 columns]

# %%
# more fast method
ex.order_types
# Out:
#          LIMIT  LIMIT_MAKER  MARKET  STOP_LOSS_LIMIT  TAKE_PROFIT_LIMIT
# symbol
# ETHBTC    True         True    True             True               True
# LTCBTC    True         True    True             True               True
# BNBBTC    True         True    True             True               True
# NEOBTC    True         True    True             True               True
# QTUMETH   True         True    True             True               True
# ...        ...          ...     ...              ...                ...
# BTCPLN    True         True    True             True               True
# ETHPLN    True         True    True             True               True
# BUSDPLN   True         True    True             True               True
# APTEUR    True         True    True             True               True
# APTTRY    True         True    True             True               True
#
# [2115 rows x 5 columns]

# %% [markdown]
# # Top gainers of the last 24 hours can be requested from exchange handler

# %%
from secret import api_key, api_secret
top = handlers.exchange.get_top_gainers(decimal_mode=False, api_key=api_key, api_secret=api_secret)
top
# Out:
#           priceChangePercent        volume  BUSD_value   BUSD_volume
# symbol
# APTBTC               679.863  3.879642e+06      7.6522  2.968780e+07
# APTUSDT              665.170  5.920394e+07      7.6522  4.530404e+08
# APTBUSD              665.154  3.356699e+07      7.6522  2.568613e+08
# VIDTBTC               32.708  1.171736e+07      0.3527  4.132711e+06
# VIDTUSDT              31.141  7.973461e+07      0.3527  2.812240e+07
# ...                      ...           ...         ...           ...
# CVPBUSD              -16.832  1.453944e+07      0.4437  6.451148e+06
# CVPUSDT              -16.842  1.493756e+07      0.4437  6.627796e+06
# VIBBTC               -19.231  5.690433e+07      0.0602  3.425641e+06
# VIBETH               -19.883  1.105288e+07      0.0602  6.653836e+05
# VIBBUSD              -20.391  4.060760e+08      0.0602  2.444578e+07
#
# [1200 rows x 4 columns]

# %%
top.sort_values('BUSD_volume')
# Out:
#          priceChangePercent        volume    BUSD_value   BUSD_volume
# symbol
# MASKBNB              -0.767  5.336000e+02      1.058000  5.645488e+02
# MITHBNB              -2.949  1.050590e+05      0.018994  1.995489e+03
# BNXBNB                0.200  1.446200e+01    148.600000  2.149053e+03
# BUSDVAI               0.192  2.425700e+03      1.000000  2.425700e+03
# CHRETH               -0.461  2.409690e+04      0.139800  3.368747e+03
# ...                     ...           ...           ...           ...
# APTUSDT             665.170  5.920394e+07      7.652200  4.530404e+08
# ETHUSDT              -0.895  4.281229e+05   1297.250000  5.553825e+08
# BTCBUSD              -1.095  1.304389e+05  19187.650000  2.502816e+09
# BTCUSDT              -1.099  2.165749e+05  19187.650000  4.155564e+09
# BDOTDOT               0.014  2.421412e+04           NaN           NaN
#
# [1200 rows x 4 columns]

# %% [markdown]
# # Thank you

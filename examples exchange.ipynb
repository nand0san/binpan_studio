# %%
from IPython.display import display, HTML

display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from binpan import binpan
from binpan import handlers
import pandas as pd

# %%
# !python -V
# Out:
# Python 3.11.2

# %% [markdown]
# # Exchange examples

# %%
ex = binpan.Exchange()

# %%
binpan.__version__
# Out:
# '0.4.19'

# %% [markdown]
# # Main dataframe with symbols info

# %%
ex.df
# Out:
#             status baseAsset  baseAssetPrecision quoteAsset  quotePrecision  quoteAssetPrecision  baseCommissionPrecision  quoteCommissionPrecision                                         orderTypes  icebergAllowed  ...  isSpotTradingAllowed
# symbol                                                                                                                                                                                                                  ...
# ETHBTC     TRADING       ETH                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True  \
# LTCBTC     TRADING       LTC                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# BNBBTC     TRADING       BNB                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# NEOBTC     TRADING       NEO                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# QTUMETH    TRADING      QTUM                   8        ETH               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# ...            ...       ...                 ...        ...             ...                  ...                      ...                       ...                                                ...             ...  ...                   ...
# RNDRTRY    TRADING      RNDR                   8        TRY               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# PEPEUSDT   TRADING      PEPE                   2       USDT               8                    8                        2                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# PEPETUSD   TRADING      PEPE                   2       TUSD               8                    8                        2                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# FLOKIUSDT  TRADING     FLOKI                   2       USDT               8                    8                        2                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# FLOKITUSD  TRADING     FLOKI                   2       TUSD               8                    8                        2                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
#
#            isMarginTradingAllowed                                            filters  defaultSelfTradePreventionMode                  allowedSelfTradePreventionModes  SPOT MARGIN TRD_GRP_004 TRD_GRP_005  TRD_GRP_006
# symbol
# ETHBTC                       True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# LTCBTC                       True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# BNBBTC                       True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# NEOBTC                       True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True       False       False        False
# QTUMETH                     False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# ...                           ...                                                ...                             ...                                              ...   ...    ...         ...         ...          ...
# RNDRTRY                     False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# PEPEUSDT                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# PEPETUSD                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# FLOKIUSDT                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# FLOKITUSD                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
#
# [2212 rows x 24 columns]

# %% [markdown]
# ## Dataframe with order types by symbol

# %%
ex.order_types
# Out:
#            LIMIT  LIMIT_MAKER  MARKET  STOP_LOSS_LIMIT  TAKE_PROFIT_LIMIT
# symbol
# ETHBTC      True         True    True             True               True
# LTCBTC      True         True    True             True               True
# BNBBTC      True         True    True             True               True
# NEOBTC      True         True    True             True               True
# QTUMETH     True         True    True             True               True
# ...          ...          ...     ...              ...                ...
# RNDRTRY     True         True    True             True               True
# PEPEUSDT    True         True    True             True               True
# PEPETUSD    True         True    True             True               True
# FLOKIUSDT   True         True    True             True               True
# FLOKITUSD   True         True    True             True               True
#
# [2212 rows x 5 columns]

# %% [markdown]
# ## Any dataframe reponse can be applied pandas methods

# %%
ex.order_types[ex.order_types['MARKET'].isna()]
# Out:
# Empty DataFrame
# Columns: [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, TAKE_PROFIT_LIMIT]
# Index: []

# %% [markdown]
# ## Update the exchange info from API

# %%
di = ex.update_info()
di[list(di.keys())[0]]
# Out:
# {'symbol': 'ETHBTC',
#  'status': 'TRADING',
#  'baseAsset': 'ETH',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'BTC',
#  'quotePrecision': 8,
#  'quoteAssetPrecision': 8,
#  'baseCommissionPrecision': 8,
#  'quoteCommissionPrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'ocoAllowed': True,
#  'quoteOrderQtyMarketAllowed': True,
#  'allowTrailingStop': True,
#  'cancelReplaceAllowed': True,
#  'isSpotTradingAllowed': True,
#  'isMarginTradingAllowed': True,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.00000100',
#    'maxPrice': '922327.00000000',
#    'tickSize': '0.00000100'},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.00010000',
#    'maxQty': '100000.00000000',
#    'stepSize': '0.00010000'},
#   {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#   {'filterType': 'MARKET_LOT_SIZE',
#    'minQty': '0.00000000',
#    'maxQty': '1404.91179937',
#    'stepSize': '0.00000000'},
#   {'filterType': 'TRAILING_DELTA',
#    'minTrailingAboveDelta': 10,
#    'maxTrailingAboveDelta': 2000,
#    'minTrailingBelowDelta': 10,
#    'maxTrailingBelowDelta': 2000},
#   {'filterType': 'PERCENT_PRICE_BY_SIDE',
#    'bidMultiplierUp': '5',
#    'bidMultiplierDown': '0.2',
#    'askMultiplierUp': '5',
#    'askMultiplierDown': '0.2',
#    'avgPriceMins': 5},
#   {'filterType': 'NOTIONAL',
#    'minNotional': '0.00010000',
#    'applyMinToMarket': True,
#    'maxNotional': '9000000.00000000',
#    'applyMaxToMarket': False,
#    'avgPriceMins': 5},
#   {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#   {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#  'permissions': ['SPOT',
#   'MARGIN',
#   'TRD_GRP_004',
#   'TRD_GRP_005',
#   'TRD_GRP_006'],
#  'defaultSelfTradePreventionMode': 'NONE',
#  'allowedSelfTradePreventionModes': ['NONE',
#   'EXPIRE_TAKER',
#   'EXPIRE_MAKER',
#   'EXPIRE_BOTH']}

# %% [markdown]
# ## Symbol's info can be requested anytime without calling API again

# %%
infd = ex.info_dic
infd['ETHUSDT']
# Out:
# {'symbol': 'ETHUSDT',
#  'status': 'TRADING',
#  'baseAsset': 'ETH',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'USDT',
#  'quotePrecision': 8,
#  'quoteAssetPrecision': 8,
#  'baseCommissionPrecision': 8,
#  'quoteCommissionPrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'ocoAllowed': True,
#  'quoteOrderQtyMarketAllowed': True,
#  'allowTrailingStop': True,
#  'cancelReplaceAllowed': True,
#  'isSpotTradingAllowed': True,
#  'isMarginTradingAllowed': True,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.01000000',
#    'maxPrice': '1000000.00000000',
#    'tickSize': '0.01000000'},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.00010000',
#    'maxQty': '9000.00000000',
#    'stepSize': '0.00010000'},
#   {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#   {'filterType': 'MARKET_LOT_SIZE',
#    'minQty': '0.00000000',
#    'maxQty': '2333.90010875',
#    'stepSize': '0.00000000'},
#   {'filterType': 'TRAILING_DELTA',
#    'minTrailingAboveDelta': 10,
#    'maxTrailingAboveDelta': 2000,
#    'minTrailingBelowDelta': 10,
#    'maxTrailingBelowDelta': 2000},
#   {'filterType': 'PERCENT_PRICE_BY_SIDE',
#    'bidMultiplierUp': '5',
#    'bidMultiplierDown': '0.2',
#    'askMultiplierUp': '5',
#    'askMultiplierDown': '0.2',
#    'avgPriceMins': 5},
#   {'filterType': 'NOTIONAL',
#    'minNotional': '10.00000000',
#    'applyMinToMarket': True,
#    'maxNotional': '9000000.00000000',
#    'applyMaxToMarket': False,
#    'avgPriceMins': 5},
#   {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#   {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#  'permissions': ['SPOT',
#   'MARGIN',
#   'TRD_GRP_004',
#   'TRD_GRP_005',
#   'TRD_GRP_006'],
#  'defaultSelfTradePreventionMode': 'NONE',
#  'allowedSelfTradePreventionModes': ['NONE',
#   'EXPIRE_TAKER',
#   'EXPIRE_MAKER',
#   'EXPIRE_BOTH']}

# %% [markdown]
# # Some methods to obtain info about symbols, fees, coins, etc...

# %%
ex.filter('BTCUSDT')
# Out:
# {'PRICE_FILTER_minPrice': '0.01000000',
#  'PRICE_FILTER_maxPrice': '1000000.00000000',
#  'PRICE_FILTER_tickSize': '0.01000000',
#  'LOT_SIZE_minQty': '0.00001000',
#  'LOT_SIZE_maxQty': '9000.00000000',
#  'LOT_SIZE_stepSize': '0.00001000',
#  'ICEBERG_PARTS_limit': 10,
#  'MARKET_LOT_SIZE_minQty': '0.00000000',
#  'MARKET_LOT_SIZE_maxQty': '137.36615031',
#  'MARKET_LOT_SIZE_stepSize': '0.00000000',
#  'TRAILING_DELTA_minTrailingAboveDelta': 10,
#  'TRAILING_DELTA_maxTrailingAboveDelta': 2000,
#  'TRAILING_DELTA_minTrailingBelowDelta': 10,
#  'TRAILING_DELTA_maxTrailingBelowDelta': 2000,
#  'PERCENT_PRICE_BY_SIDE_bidMultiplierUp': '5',
#  'PERCENT_PRICE_BY_SIDE_bidMultiplierDown': '0.2',
#  'PERCENT_PRICE_BY_SIDE_askMultiplierUp': '5',
#  'PERCENT_PRICE_BY_SIDE_askMultiplierDown': '0.2',
#  'PERCENT_PRICE_BY_SIDE_avgPriceMins': 5,
#  'NOTIONAL_minNotional': '10.00000000',
#  'NOTIONAL_applyMinToMarket': True,
#  'NOTIONAL_maxNotional': '9000000.00000000',
#  'NOTIONAL_applyMaxToMarket': False,
#  'NOTIONAL_avgPriceMins': 5,
#  'MAX_NUM_ORDERS_maxNumOrders': 200,
#  'MAX_NUM_ALGO_ORDERS_maxNumAlgoOrders': 5}

# %%
ex.fee('BTCUSDT')
# Out:
# makerCommission    0.001
# takerCommission    0.001
# Name: BTCUSDT, dtype: float64

# %%
ex.coin('BTC')
# Out:
# depositAllEnable         True
# withdrawAllEnable        True
# name                  Bitcoin
# free                 0.000044
# locked                      0
# freeze                      0
# withdrawing                 0
# ipoing                      0
# ipoable                     0
# storage                     0
# isLegalMoney            False
# trading                  True
# Name: BTC, dtype: object

# %% [markdown]
# ### Info about Binance blockchain networks for any coin

# %%
ex.network('BTC')
# Out:
#         network  withdrawIntegerMultiple  isDefault  depositEnable  withdrawEnable depositDesc                                       withdrawDesc                                        specialTips                                specialWithdrawTips
# coin
# BTC         ETH             1.000000e-08      False           True            True                                                                                                                    You are withdrawing Binance Wrapped BTC (BBTC)...  \
# BTC         BSC             1.000000e-08      False           True            True                                                                                                                    The network you have selected is BSC. Please e...
# BTC         BTC             1.000000e-08       True           True            True
# BTC         BNB             1.000000e-08      False           True           False              Withdrawal for this token is not supported, pl...  Both a memo/tag and an address are required to...                                                NaN
# BTC   SEGWITBTC             1.000000e-08      False           True           False              Withdrawal for this token is not supported, pl...
#
#                          name  ...   withdrawMax minConfirm unLockConfirm sameAddress  estimatedArrivalTime   busy                            country                   contractAddressUrl                             contractAddress  depositDust
# coin                           ...
# BTC          Ethereum (ERC20)  ...  1.000000e+10         12            64       False                     5  False  AE,BINANCE_BAHRAIN_BSC,custody,KZ          https://etherscan.io/token/  0x9be89d2a4cd102d8fecc6bf9da793be995c22541          NaN
# BTC   BNB Smart Chain (BEP20)  ...  1.000000e+10         15             0       False                     5  False  AE,BINANCE_BAHRAIN_BSC,custody,KZ           https://bscscan.com/token/  0x7130d2a12b9bcbfae4f2634d864a1ee1ce3ead9c          NaN
# BTC                   Bitcoin  ...  7.500000e+03          1             2       False                    60  False  AE,BINANCE_BAHRAIN_BSC,custody,KZ                                  NaN                                         NaN          NaN
# BTC   BNB Beacon Chain (BEP2)  ...  1.000000e+10          1             0        True                     5  False          AE,BINANCE_BAHRAIN_BSC,KZ  https://binance.mintscan.io/assets/                                    BTCB-1DE      0.00001
# BTC               BTC(SegWit)  ...  1.000000e+10          1             2       False                     5  False                                NaN                                  NaN                                         NaN          NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Filter symbols with a coin as base or quote or both.

# %%
l = ex.get_symbols('BTC', base=False, quote=True)
l[:15]
# Out:
# ['ETHBTC',
#  'LTCBTC',
#  'BNBBTC',
#  'NEOBTC',
#  'BCCBTC',
#  'GASBTC',
#  'HSRBTC',
#  'MCOBTC',
#  'WTCBTC',
#  'LRCBTC',
#  'QTUMBTC',
#  'YOYOBTC',
#  'OMGBTC',
#  'ZRXBTC',
#  'STRATBTC']

# %% [markdown]
# ## Other method to show the symbols dataframe

# %%
ex.get_df()
# Out:
#             status baseAsset  baseAssetPrecision quoteAsset  quotePrecision  quoteAssetPrecision  baseCommissionPrecision  quoteCommissionPrecision                                         orderTypes  icebergAllowed  ...  isSpotTradingAllowed
# symbol                                                                                                                                                                                                                  ...
# ETHBTC     TRADING       ETH                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True  \
# LTCBTC     TRADING       LTC                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# BNBBTC     TRADING       BNB                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# NEOBTC     TRADING       NEO                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# QTUMETH    TRADING      QTUM                   8        ETH               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# ...            ...       ...                 ...        ...             ...                  ...                      ...                       ...                                                ...             ...  ...                   ...
# RNDRTRY    TRADING      RNDR                   8        TRY               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# PEPEUSDT   TRADING      PEPE                   2       USDT               8                    8                        2                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# PEPETUSD   TRADING      PEPE                   2       TUSD               8                    8                        2                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# FLOKIUSDT  TRADING     FLOKI                   2       USDT               8                    8                        2                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# FLOKITUSD  TRADING     FLOKI                   2       TUSD               8                    8                        2                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
#
#            isMarginTradingAllowed                                            filters  defaultSelfTradePreventionMode                  allowedSelfTradePreventionModes  SPOT MARGIN TRD_GRP_004 TRD_GRP_005  TRD_GRP_006
# symbol
# ETHBTC                       True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# LTCBTC                       True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# BNBBTC                       True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# NEOBTC                       True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True       False       False        False
# QTUMETH                     False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# ...                           ...                                                ...                             ...                                              ...   ...    ...         ...         ...          ...
# RNDRTRY                     False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# PEPEUSDT                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# PEPETUSD                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# FLOKIUSDT                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# FLOKITUSD                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
#
# [2212 rows x 24 columns]

# %% [markdown]
# ## Order types supported by symbols

# %%
ex.get_order_types()
# Out:
#            LIMIT  LIMIT_MAKER  MARKET  STOP_LOSS_LIMIT  TAKE_PROFIT_LIMIT
# symbol
# ETHBTC      True         True    True             True               True
# LTCBTC      True         True    True             True               True
# BNBBTC      True         True    True             True               True
# NEOBTC      True         True    True             True               True
# QTUMETH     True         True    True             True               True
# ...          ...          ...     ...              ...                ...
# RNDRTRY     True         True    True             True               True
# PEPEUSDT    True         True    True             True               True
# PEPETUSD    True         True    True             True               True
# FLOKIUSDT   True         True    True             True               True
# FLOKITUSD   True         True    True             True               True
#
# [2212 rows x 5 columns]

# %%
# more fast method
ex.order_types
# Out:
#            LIMIT  LIMIT_MAKER  MARKET  STOP_LOSS_LIMIT  TAKE_PROFIT_LIMIT
# symbol
# ETHBTC      True         True    True             True               True
# LTCBTC      True         True    True             True               True
# BNBBTC      True         True    True             True               True
# NEOBTC      True         True    True             True               True
# QTUMETH     True         True    True             True               True
# ...          ...          ...     ...              ...                ...
# RNDRTRY     True         True    True             True               True
# PEPEUSDT    True         True    True             True               True
# PEPETUSD    True         True    True             True               True
# FLOKIUSDT   True         True    True             True               True
# FLOKITUSD   True         True    True             True               True
#
# [2212 rows x 5 columns]

# %% [markdown]
# # Top gainers of the last 24 hours can be requested from exchange handler

# %%
from secret import api_key, api_secret
top = handlers.exchange.get_top_gainers(decimal_mode=False, api_key=api_key, api_secret=api_secret)
# this can take a while
top
# Out:
#            priceChangePercent        volume  BUSD_value   BUSD_volume
# symbol
# PEPEUSDT               65.482  2.709004e+13    0.000003  8.796339e+07
# PEPETUSD               64.141  9.509570e+11    0.000003  3.087829e+06
# UMABUSD                39.876  3.603104e+06    2.936000  1.057871e+07
# UMAUSDT                39.810  2.555648e+07    2.936000  7.503383e+07
# UMABTC                 36.777  1.658493e+06    2.936000  4.869337e+06
# ...                       ...           ...         ...           ...
# AERGOBUSD             -10.574  5.568009e+07    0.129400  7.205004e+06
# AERGOBTC              -12.749  8.508546e+06    0.129400  1.101006e+06
# RADBUSD               -18.868  6.672482e+06    3.395000  2.265308e+07
# RADUSDT               -18.944  4.326653e+07    3.395000  1.468899e+08
# RADBTC                -20.592  4.044745e+06    3.395000  1.373191e+07
#
# [1170 rows x 4 columns]

# %%
top.sort_values('BUSD_volume')
# Out:
#           priceChangePercent        volume  BUSD_value   BUSD_volume
# symbol
# KNCBNB                 3.188  4.256500e+02      0.6840  2.911446e+02
# ENSBNB                 0.545  8.155000e+01     12.0400  9.818620e+02
# REIBNB                -0.481  5.851290e+04      0.0270  1.579848e+03
# ARBNB                  2.355  2.701200e+02      7.9200  2.139350e+03
# WRXBNB                 0.000  1.479250e+04      0.1563  2.312068e+03
# ...                      ...           ...         ...           ...
# USDCUSDT              -0.040  3.338689e+08      0.9999  3.338356e+08
# ETHUSDT                5.987  5.340899e+05   1987.0300  1.061253e+09
# BTCTUSD                2.251  4.709048e+04  29482.4800  1.388344e+09
# BTCUSDT                2.266  5.756727e+04  29482.4800  1.697226e+09
# BDOTDOT               -0.023  3.271546e+04         NaN           NaN
#
# [1170 rows x 4 columns]

# %% [markdown]
# # Most traded in some quote

# %%
data = handlers.exchange.get_top_gainers(decimal_mode=True, api_key=api_key, api_secret=api_secret, margin_required=True, drop_legal=True, my_quote='BTC', sort_by_column="BTC_volume")

# %%
data
# Out:
#            priceChangePercent        volume     BTC_value    BTC_volume
# symbol
# SHIBUSDT               -0.302  1.905248e+12  9.899010e-06  1.886007e+07
# LUNCUSDT               -1.444  1.051036e+11  1.023598e-04  1.075837e+07
# LUNCBUSD               -1.501  6.424115e+10  1.023598e-04  6.575709e+06
# MASKUSDT                1.329  1.247892e+06  4.498550e+00  5.613706e+06
# SHIBBUSD               -0.302  5.605215e+11  9.899010e-06  5.548607e+06
# ...                       ...           ...           ...           ...
# CHRBTC                 -1.143  4.146700e+04  5.190000e-06  2.152137e-01
# PONDBTC                -2.941  5.448610e+05  3.300000e-07  1.798041e-01
# COCOSUSDT              -2.952  4.767106e+06  3.000000e-08  1.430132e-01
# LUNAUSDT               -0.640  2.796184e+06  1.000000e-08  2.796184e-02
# LUNABUSD               -0.640  9.037757e+05  1.000000e-08  9.037757e-03
#
# [560 rows x 4 columns]

# %%
quotes = handlers.exchange.get_quotes_dic()

# %%
symbols = [i for i in data.index if quotes[i]=='BTC']

# %%
# most traded in btc quote
data.loc[symbols].head(10).index
# Out:
# Index(['ETHBTC', 'BNBBTC', 'XRPBTC', 'SOLBTC', 'UMABTC', 'ARBBTC', 'XMRBTC', 'LTCBTC', 'IDEXBTC', 'RNDRBTC'], dtype='object', name='symbol')

# %% [markdown]
# # Thank you

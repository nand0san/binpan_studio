# %%
from IPython.display import display, HTML

display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from binpan import binpan
from binpan import handlers
import pandas as pd

# %% [markdown]
# # Exchange examples

# %%
ex = binpan.Exchange()

# %%
binpan.__version__
# Out:
# '0.2.49'

# %% [markdown]
# # Main dataframe with symbols info

# %%
ex.df
# Out:
#            status baseAsset  baseAssetPrecision quoteAsset  quotePrecision  quoteAssetPrecision  baseCommissionPrecision  quoteCommissionPrecision                                         orderTypes  icebergAllowed  ...  isSpotTradingAllowed  \
# symbol                                                                                                                                                                                                                 ...
# ETHBTC    TRADING       ETH                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# LTCBTC    TRADING       LTC                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# BNBBTC    TRADING       BNB                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# NEOBTC    TRADING       NEO                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# QTUMETH   TRADING      QTUM                   8        ETH               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# ...           ...       ...                 ...        ...             ...                  ...                      ...                       ...                                                ...             ...  ...                   ...
# RPLBUSD   TRADING       RPL                   8       BUSD               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# RPLUSDT   TRADING       RPL                   8       USDT               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# PROSUSDT  TRADING      PROS                   8       USDT               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# FETTRY    TRADING       FET                   8        TRY               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# GFTBUSD   TRADING       GFT                   8       BUSD               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
#
#           isMarginTradingAllowed                                            filters  defaultSelfTradePreventionMode                  allowedSelfTradePreventionModes  SPOT MARGIN TRD_GRP_004 TRD_GRP_005  TRD_GRP_006
# symbol
# ETHBTC                      True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# LTCBTC                      True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# BNBBTC                      True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# NEOBTC                      True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True       False       False        False
# QTUMETH                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True       False       False        False
# ...                          ...                                                ...                             ...                                              ...   ...    ...         ...         ...          ...
# RPLBUSD                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# RPLUSDT                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# PROSUSDT                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# FETTRY                     False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# GFTBUSD                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
#
# [2145 rows x 24 columns]

# %% [markdown]
# ## Dataframe with order types by symbol

# %%
ex.order_types
# Out:
#           LIMIT  LIMIT_MAKER  MARKET  STOP_LOSS_LIMIT  TAKE_PROFIT_LIMIT
# symbol
# ETHBTC     True         True    True             True               True
# LTCBTC     True         True    True             True               True
# BNBBTC     True         True    True             True               True
# NEOBTC     True         True    True             True               True
# QTUMETH    True         True    True             True               True
# ...         ...          ...     ...              ...                ...
# RPLBUSD    True         True    True             True               True
# RPLUSDT    True         True    True             True               True
# PROSUSDT   True         True    True             True               True
# FETTRY     True         True    True             True               True
# GFTBUSD    True         True    True             True               True
#
# [2145 rows x 5 columns]

# %% [markdown]
# ## Any dataframe reponse can be applied pandas methods

# %%
ex.order_types[ex.order_types['MARKET'].isna()]
# Out:
# Empty DataFrame
# Columns: [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, TAKE_PROFIT_LIMIT]
# Index: []

# %% [markdown]
# ## Update the exchange info from API

# %%
di = ex.update_info()
di[list(di.keys())[0]]
# Out:
# {'symbol': 'ETHBTC',
#  'status': 'TRADING',
#  'baseAsset': 'ETH',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'BTC',
#  'quotePrecision': 8,
#  'quoteAssetPrecision': 8,
#  'baseCommissionPrecision': 8,
#  'quoteCommissionPrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'ocoAllowed': True,
#  'quoteOrderQtyMarketAllowed': True,
#  'allowTrailingStop': True,
#  'cancelReplaceAllowed': True,
#  'isSpotTradingAllowed': True,
#  'isMarginTradingAllowed': True,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.00000100',
#    'maxPrice': '922327.00000000',
#    'tickSize': '0.00000100'},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.00010000',
#    'maxQty': '100000.00000000',
#    'stepSize': '0.00010000'},
#   {'filterType': 'MIN_NOTIONAL',
#    'minNotional': '0.00010000',
#    'applyToMarket': True,
#    'avgPriceMins': 5},
#   {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#   {'filterType': 'MARKET_LOT_SIZE',
#    'minQty': '0.00000000',
#    'maxQty': '1291.07284173',
#    'stepSize': '0.00000000'},
#   {'filterType': 'TRAILING_DELTA',
#    'minTrailingAboveDelta': 10,
#    'maxTrailingAboveDelta': 2000,
#    'minTrailingBelowDelta': 10,
#    'maxTrailingBelowDelta': 2000},
#   {'filterType': 'PERCENT_PRICE_BY_SIDE',
#    'bidMultiplierUp': '5',
#    'bidMultiplierDown': '0.2',
#    'askMultiplierUp': '5',
#    'askMultiplierDown': '0.2',
#    'avgPriceMins': 5},
#   {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#   {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#  'permissions': ['SPOT',
#   'MARGIN',
#   'TRD_GRP_004',
#   'TRD_GRP_005',
#   'TRD_GRP_006'],
#  'defaultSelfTradePreventionMode': 'NONE',
#  'allowedSelfTradePreventionModes': ['NONE',
#   'EXPIRE_TAKER',
#   'EXPIRE_MAKER',
#   'EXPIRE_BOTH']}

# %% [markdown]
# ## Symbol's info can be requested anytime without calling API again

# %%
infd = ex.info_dic
infd['ETHUSDT']
# Out:
# {'symbol': 'ETHUSDT',
#  'status': 'TRADING',
#  'baseAsset': 'ETH',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'USDT',
#  'quotePrecision': 8,
#  'quoteAssetPrecision': 8,
#  'baseCommissionPrecision': 8,
#  'quoteCommissionPrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'ocoAllowed': True,
#  'quoteOrderQtyMarketAllowed': True,
#  'allowTrailingStop': True,
#  'cancelReplaceAllowed': True,
#  'isSpotTradingAllowed': True,
#  'isMarginTradingAllowed': True,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.01000000',
#    'maxPrice': '1000000.00000000',
#    'tickSize': '0.01000000'},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.00010000',
#    'maxQty': '9000.00000000',
#    'stepSize': '0.00010000'},
#   {'filterType': 'MIN_NOTIONAL',
#    'minNotional': '10.00000000',
#    'applyToMarket': True,
#    'avgPriceMins': 5},
#   {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#   {'filterType': 'MARKET_LOT_SIZE',
#    'minQty': '0.00000000',
#    'maxQty': '4002.47056638',
#    'stepSize': '0.00000000'},
#   {'filterType': 'TRAILING_DELTA',
#    'minTrailingAboveDelta': 10,
#    'maxTrailingAboveDelta': 2000,
#    'minTrailingBelowDelta': 10,
#    'maxTrailingBelowDelta': 2000},
#   {'filterType': 'PERCENT_PRICE_BY_SIDE',
#    'bidMultiplierUp': '5',
#    'bidMultiplierDown': '0.2',
#    'askMultiplierUp': '5',
#    'askMultiplierDown': '0.2',
#    'avgPriceMins': 5},
#   {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#   {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#  'permissions': ['SPOT',
#   'MARGIN',
#   'TRD_GRP_004',
#   'TRD_GRP_005',
#   'TRD_GRP_006'],
#  'defaultSelfTradePreventionMode': 'NONE',
#  'allowedSelfTradePreventionModes': ['NONE',
#   'EXPIRE_TAKER',
#   'EXPIRE_MAKER',
#   'EXPIRE_BOTH']}

# %% [markdown]
# # Some methods to obtain info about symbols, fees, coins, etc...

# %%
ex.filter('BTCUSDT')
# Out:
# {'PRICE_FILTER_minPrice': '0.01000000',
#  'PRICE_FILTER_maxPrice': '1000000.00000000',
#  'PRICE_FILTER_tickSize': '0.01000000',
#  'LOT_SIZE_minQty': '0.00001000',
#  'LOT_SIZE_maxQty': '9000.00000000',
#  'LOT_SIZE_stepSize': '0.00001000',
#  'MIN_NOTIONAL_minNotional': '10.00000000',
#  'MIN_NOTIONAL_applyToMarket': True,
#  'MIN_NOTIONAL_avgPriceMins': 5,
#  'ICEBERG_PARTS_limit': 10,
#  'MARKET_LOT_SIZE_minQty': '0.00000000',
#  'MARKET_LOT_SIZE_maxQty': '256.11448765',
#  'MARKET_LOT_SIZE_stepSize': '0.00000000',
#  'TRAILING_DELTA_minTrailingAboveDelta': 10,
#  'TRAILING_DELTA_maxTrailingAboveDelta': 2000,
#  'TRAILING_DELTA_minTrailingBelowDelta': 10,
#  'TRAILING_DELTA_maxTrailingBelowDelta': 2000,
#  'PERCENT_PRICE_BY_SIDE_bidMultiplierUp': '5',
#  'PERCENT_PRICE_BY_SIDE_bidMultiplierDown': '0.2',
#  'PERCENT_PRICE_BY_SIDE_askMultiplierUp': '5',
#  'PERCENT_PRICE_BY_SIDE_askMultiplierDown': '0.2',
#  'PERCENT_PRICE_BY_SIDE_avgPriceMins': 5,
#  'MAX_NUM_ORDERS_maxNumOrders': 200,
#  'MAX_NUM_ALGO_ORDERS_maxNumAlgoOrders': 5}

# %%
ex.fee('BTCUSDT')
# Out:
# makerCommission    0.0
# takerCommission    0.0
# Name: BTCUSDT, dtype: float64

# %%
ex.coin('BTC')
# Out:
# depositAllEnable         True
# withdrawAllEnable        True
# name                  Bitcoin
# free                 0.000044
# locked                      0
# freeze                      0
# withdrawing                 0
# ipoing                      0
# ipoable                     0
# storage                     0
# isLegalMoney            False
# trading                  True
# Name: BTC, dtype: object

# %% [markdown]
# ### Info about Binance blockchain networks for any coin

# %%
ex.network('BTC')
# Out:
#         network  withdrawIntegerMultiple  isDefault  depositEnable  withdrawEnable depositDesc                                       withdrawDesc                                        specialTips                                specialWithdrawTips  \
# coin
# BTC         BSC             1.000000e-08      False           True            True                                                                                                                    The network you have selected is BSC. Please e...
# BTC   SEGWITBTC             1.000000e-08      False           True           False              The wallet is currently undergoing maintenance...
# BTC         BNB             1.000000e-08      False           True            True                                                                 Please enter both MEMO and Address data, which...                                                NaN
# BTC         ETH             1.000000e-08      False           True            True                                                                 This deposit address supports ERC20 BBTC token...  You are withdrawing Binance Wrapped BTC (BBTC)...
# BTC         BTC             1.000000e-08       True           True            True
#
#                          name  ...  withdrawFee withdrawMin   withdrawMax minConfirm  unLockConfirm  sameAddress  estimatedArrivalTime   busy                            country  depositDust
# coin                           ...
# BTC   BNB Smart Chain (BEP20)  ...     0.000004    0.000009  1.000000e+10         15              0        False                     5  False  AE,BINANCE_BAHRAIN_BSC,custody,KZ          NaN
# BTC               BTC(SegWit)  ...     0.000500    0.001000  1.000000e+10          1              2        False                     5  False                                NaN          NaN
# BTC   BNB Beacon Chain (BEP2)  ...     0.000007    0.000014  1.000000e+10          1              0         True                     5  False          AE,BINANCE_BAHRAIN_BSC,KZ      0.00001
# BTC          Ethereum (ERC20)  ...     0.000180    0.000360  1.000000e+10         12              0        False                     5  False  AE,BINANCE_BAHRAIN_BSC,custody,KZ          NaN
# BTC                   Bitcoin  ...     0.000200    0.001000  7.500000e+03          1              2        False                    60  False  AE,BINANCE_BAHRAIN_BSC,custody,KZ          NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Filter symbols with a coin as base or quote or both.

# %%
l = ex.get_symbols('BTC', base=False, quote=True)
l[:15]
# Out:
# ['ETHBTC',
#  'LTCBTC',
#  'BNBBTC',
#  'NEOBTC',
#  'BCCBTC',
#  'GASBTC',
#  'HSRBTC',
#  'MCOBTC',
#  'WTCBTC',
#  'LRCBTC',
#  'QTUMBTC',
#  'YOYOBTC',
#  'OMGBTC',
#  'ZRXBTC',
#  'STRATBTC']

# %% [markdown]
# ## Other method to show the symbols dataframe

# %%
ex.get_df()
# Out:
#            status baseAsset  baseAssetPrecision quoteAsset  quotePrecision  quoteAssetPrecision  baseCommissionPrecision  quoteCommissionPrecision                                         orderTypes  icebergAllowed  ...  isSpotTradingAllowed  \
# symbol                                                                                                                                                                                                                 ...
# ETHBTC    TRADING       ETH                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# LTCBTC    TRADING       LTC                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# BNBBTC    TRADING       BNB                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# NEOBTC    TRADING       NEO                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# QTUMETH   TRADING      QTUM                   8        ETH               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# ...           ...       ...                 ...        ...             ...                  ...                      ...                       ...                                                ...             ...  ...                   ...
# RPLBUSD   TRADING       RPL                   8       BUSD               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# RPLUSDT   TRADING       RPL                   8       USDT               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# PROSUSDT  TRADING      PROS                   8       USDT               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# FETTRY    TRADING       FET                   8        TRY               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# GFTBUSD   TRADING       GFT                   8       BUSD               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
#
#           isMarginTradingAllowed                                            filters  defaultSelfTradePreventionMode                  allowedSelfTradePreventionModes  SPOT MARGIN TRD_GRP_004 TRD_GRP_005  TRD_GRP_006
# symbol
# ETHBTC                      True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# LTCBTC                      True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# BNBBTC                      True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# NEOBTC                      True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True       False       False        False
# QTUMETH                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True       False       False        False
# ...                          ...                                                ...                             ...                                              ...   ...    ...         ...         ...          ...
# RPLBUSD                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# RPLUSDT                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# PROSUSDT                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# FETTRY                     False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# GFTBUSD                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
#
# [2145 rows x 24 columns]

# %% [markdown]
# ## Order types supported by symbols

# %%
ex.get_order_types()
# Out:
#           LIMIT  LIMIT_MAKER  MARKET  STOP_LOSS_LIMIT  TAKE_PROFIT_LIMIT
# symbol
# ETHBTC     True         True    True             True               True
# LTCBTC     True         True    True             True               True
# BNBBTC     True         True    True             True               True
# NEOBTC     True         True    True             True               True
# QTUMETH    True         True    True             True               True
# ...         ...          ...     ...              ...                ...
# RPLBUSD    True         True    True             True               True
# RPLUSDT    True         True    True             True               True
# PROSUSDT   True         True    True             True               True
# FETTRY     True         True    True             True               True
# GFTBUSD    True         True    True             True               True
#
# [2145 rows x 5 columns]

# %%
# more fast method
ex.order_types
# Out:
#           LIMIT  LIMIT_MAKER  MARKET  STOP_LOSS_LIMIT  TAKE_PROFIT_LIMIT
# symbol
# ETHBTC     True         True    True             True               True
# LTCBTC     True         True    True             True               True
# BNBBTC     True         True    True             True               True
# NEOBTC     True         True    True             True               True
# QTUMETH    True         True    True             True               True
# ...         ...          ...     ...              ...                ...
# RPLBUSD    True         True    True             True               True
# RPLUSDT    True         True    True             True               True
# PROSUSDT   True         True    True             True               True
# FETTRY     True         True    True             True               True
# GFTBUSD    True         True    True             True               True
#
# [2145 rows x 5 columns]

# %% [markdown]
# # Top gainers of the last 24 hours can be requested from exchange handler

# %%
from secret import api_key, api_secret
top = handlers.exchange.get_top_gainers(decimal_mode=False, api_key=api_key, api_secret=api_secret)
# this can take a while
top
# Out:
#           priceChangePercent        volume  BUSD_value   BUSD_volume
# symbol
# BONDBTC               29.135  3.587019e+05    5.522000  1.980752e+06
# BONDUSDT              26.841  4.225867e+06    5.522000  2.333524e+07
# BONDBUSD              26.820  5.445997e+06    5.522000  3.007279e+07
# BNXBNB                25.575  4.815639e+03  170.600000  8.215480e+05
# BNXBTC                15.032  9.254690e+03  170.600000  1.578850e+06
# ...                      ...           ...         ...           ...
# PIVXBTC              -16.454  1.087363e+07    0.339128  3.687555e+06
# FIROUSDT             -16.661  3.301776e+06    2.381000  7.861528e+06
# AMBBUSD              -16.908  2.473352e+08    0.016610  4.108238e+06
# DUSKBUSD             -17.086  3.754427e+07    0.207700  7.797945e+06
# DUSKUSDT             -17.206  9.439257e+07    0.207700  1.960534e+07
#
# [1141 rows x 4 columns]

# %%
top.sort_values('BUSD_volume')
# Out:
#          priceChangePercent        volume  BUSD_value   BUSD_volume
# symbol
# PLABNB                1.133  1.693390e+04      0.2168  3.671270e+03
# MTLETH               -6.074  4.792000e+03      0.9430  4.518856e+03
# RADBNB                2.936  2.745300e+03      1.8080  4.963502e+03
# ZRXETH               -6.003  2.549900e+04      0.2196  5.599580e+03
# BELETH               -6.910  1.407990e+04      0.5290  7.448267e+03
# ...                     ...           ...         ...           ...
# ETHBUSD              -3.334  4.634630e+05   1488.7200  6.899666e+08
# ETHUSDT              -3.430  6.610024e+05   1488.7200  9.840475e+08
# BTCBUSD              -1.555  1.497229e+05  21635.8200  3.239378e+09
# BTCUSDT              -1.633  2.944700e+05  21635.8200  6.371100e+09
# BDOTDOT               1.577  1.054032e+06         NaN           NaN
#
# [1141 rows x 4 columns]

# %% [markdown]
# # Thank you

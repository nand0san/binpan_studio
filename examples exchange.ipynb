# %%
from IPython.display import display, HTML

display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from binpan import binpan
from binpan import handlers
import pandas as pd

# %%
# !python -V
# Out:
# Python 3.11.2

# %% [markdown]
# # Exchange examples

# %%
ex = binpan.Exchange()

# %%
binpan.__version__
# Out:
# '0.4.11'

# %% [markdown]
# # Main dataframe with symbols info

# %%
ex.df
# Out:
#            status baseAsset  baseAssetPrecision quoteAsset  quotePrecision  quoteAssetPrecision  baseCommissionPrecision  quoteCommissionPrecision                                         orderTypes  icebergAllowed  ...  isSpotTradingAllowed  \
# symbol                                                                                                                                                                                                                 ...
# ETHBTC    TRADING       ETH                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# LTCBTC    TRADING       LTC                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# BNBBTC    TRADING       BNB                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# NEOBTC    TRADING       NEO                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# QTUMETH   TRADING      QTUM                   8        ETH               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# ...           ...       ...                 ...        ...             ...                  ...                      ...                       ...                                                ...             ...  ...                   ...
# SOLTUSD   TRADING       SOL                   8       TUSD               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# SSVTUSD   TRADING       SSV                   8       TUSD               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# RDNTBTC   TRADING      RDNT                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# RDNTUSDT  TRADING      RDNT                   8       USDT               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# RDNTTUSD  TRADING      RDNT                   8       TUSD               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
#
#           isMarginTradingAllowed                                            filters  defaultSelfTradePreventionMode                  allowedSelfTradePreventionModes  SPOT MARGIN TRD_GRP_004 TRD_GRP_005  TRD_GRP_006
# symbol
# ETHBTC                      True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# LTCBTC                      True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# BNBBTC                      True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# NEOBTC                      True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True       False       False        False
# QTUMETH                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# ...                          ...                                                ...                             ...                                              ...   ...    ...         ...         ...          ...
# SOLTUSD                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True       False       False        False
# SSVTUSD                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# RDNTBTC                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# RDNTUSDT                    True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True       False       False        False
# RDNTTUSD                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
#
# [2183 rows x 24 columns]

# %% [markdown]
# ## Dataframe with order types by symbol

# %%
ex.order_types
# Out:
#           LIMIT  LIMIT_MAKER  MARKET  STOP_LOSS_LIMIT  TAKE_PROFIT_LIMIT
# symbol
# ETHBTC     True         True    True             True               True
# LTCBTC     True         True    True             True               True
# BNBBTC     True         True    True             True               True
# NEOBTC     True         True    True             True               True
# QTUMETH    True         True    True             True               True
# ...         ...          ...     ...              ...                ...
# SOLTUSD    True         True    True             True               True
# SSVTUSD    True         True    True             True               True
# RDNTBTC    True         True    True             True               True
# RDNTUSDT   True         True    True             True               True
# RDNTTUSD   True         True    True             True               True
#
# [2183 rows x 5 columns]

# %% [markdown]
# ## Any dataframe reponse can be applied pandas methods

# %%
ex.order_types[ex.order_types['MARKET'].isna()]
# Out:
# Empty DataFrame
# Columns: [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, TAKE_PROFIT_LIMIT]
# Index: []

# %% [markdown]
# ## Update the exchange info from API

# %%
di = ex.update_info()
di[list(di.keys())[0]]
# Out:
# {'symbol': 'ETHBTC',
#  'status': 'TRADING',
#  'baseAsset': 'ETH',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'BTC',
#  'quotePrecision': 8,
#  'quoteAssetPrecision': 8,
#  'baseCommissionPrecision': 8,
#  'quoteCommissionPrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'ocoAllowed': True,
#  'quoteOrderQtyMarketAllowed': True,
#  'allowTrailingStop': False,
#  'cancelReplaceAllowed': True,
#  'isSpotTradingAllowed': True,
#  'isMarginTradingAllowed': True,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.00000100',
#    'maxPrice': '922327.00000000',
#    'tickSize': '0.00000100'},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.00010000',
#    'maxQty': '100000.00000000',
#    'stepSize': '0.00010000'},
#   {'filterType': 'MIN_NOTIONAL',
#    'minNotional': '0.00010000',
#    'applyToMarket': True,
#    'avgPriceMins': 5},
#   {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#   {'filterType': 'MARKET_LOT_SIZE',
#    'minQty': '0.00000000',
#    'maxQty': '1531.04556069',
#    'stepSize': '0.00000000'},
#   {'filterType': 'TRAILING_DELTA',
#    'minTrailingAboveDelta': 10,
#    'maxTrailingAboveDelta': 2000,
#    'minTrailingBelowDelta': 10,
#    'maxTrailingBelowDelta': 2000},
#   {'filterType': 'PERCENT_PRICE_BY_SIDE',
#    'bidMultiplierUp': '5',
#    'bidMultiplierDown': '0.2',
#    'askMultiplierUp': '5',
#    'askMultiplierDown': '0.2',
#    'avgPriceMins': 5},
#   {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#   {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#  'permissions': ['SPOT',
#   'MARGIN',
#   'TRD_GRP_004',
#   'TRD_GRP_005',
#   'TRD_GRP_006'],
#  'defaultSelfTradePreventionMode': 'NONE',
#  'allowedSelfTradePreventionModes': ['NONE',
#   'EXPIRE_TAKER',
#   'EXPIRE_MAKER',
#   'EXPIRE_BOTH']}

# %% [markdown]
# ## Symbol's info can be requested anytime without calling API again

# %%
infd = ex.info_dic
infd['ETHUSDT']
# Out:
# {'symbol': 'ETHUSDT',
#  'status': 'TRADING',
#  'baseAsset': 'ETH',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'USDT',
#  'quotePrecision': 8,
#  'quoteAssetPrecision': 8,
#  'baseCommissionPrecision': 8,
#  'quoteCommissionPrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'ocoAllowed': True,
#  'quoteOrderQtyMarketAllowed': True,
#  'allowTrailingStop': False,
#  'cancelReplaceAllowed': True,
#  'isSpotTradingAllowed': True,
#  'isMarginTradingAllowed': True,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.01000000',
#    'maxPrice': '1000000.00000000',
#    'tickSize': '0.01000000'},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.00010000',
#    'maxQty': '9000.00000000',
#    'stepSize': '0.00010000'},
#   {'filterType': 'MIN_NOTIONAL',
#    'minNotional': '10.00000000',
#    'applyToMarket': True,
#    'avgPriceMins': 5},
#   {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#   {'filterType': 'MARKET_LOT_SIZE',
#    'minQty': '0.00000000',
#    'maxQty': '3221.67978326',
#    'stepSize': '0.00000000'},
#   {'filterType': 'TRAILING_DELTA',
#    'minTrailingAboveDelta': 10,
#    'maxTrailingAboveDelta': 2000,
#    'minTrailingBelowDelta': 10,
#    'maxTrailingBelowDelta': 2000},
#   {'filterType': 'PERCENT_PRICE_BY_SIDE',
#    'bidMultiplierUp': '5',
#    'bidMultiplierDown': '0.2',
#    'askMultiplierUp': '5',
#    'askMultiplierDown': '0.2',
#    'avgPriceMins': 5},
#   {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#   {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#  'permissions': ['SPOT',
#   'MARGIN',
#   'TRD_GRP_004',
#   'TRD_GRP_005',
#   'TRD_GRP_006'],
#  'defaultSelfTradePreventionMode': 'NONE',
#  'allowedSelfTradePreventionModes': ['NONE',
#   'EXPIRE_TAKER',
#   'EXPIRE_MAKER',
#   'EXPIRE_BOTH']}

# %% [markdown]
# # Some methods to obtain info about symbols, fees, coins, etc...

# %%
ex.filter('BTCUSDT')
# Out:
# {'PRICE_FILTER_minPrice': '0.01000000',
#  'PRICE_FILTER_maxPrice': '1000000.00000000',
#  'PRICE_FILTER_tickSize': '0.01000000',
#  'LOT_SIZE_minQty': '0.00001000',
#  'LOT_SIZE_maxQty': '9000.00000000',
#  'LOT_SIZE_stepSize': '0.00001000',
#  'MIN_NOTIONAL_minNotional': '10.00000000',
#  'MIN_NOTIONAL_applyToMarket': True,
#  'MIN_NOTIONAL_avgPriceMins': 5,
#  'ICEBERG_PARTS_limit': 10,
#  'MARKET_LOT_SIZE_minQty': '0.00000000',
#  'MARKET_LOT_SIZE_maxQty': '161.31689747',
#  'MARKET_LOT_SIZE_stepSize': '0.00000000',
#  'TRAILING_DELTA_minTrailingAboveDelta': 10,
#  'TRAILING_DELTA_maxTrailingAboveDelta': 2000,
#  'TRAILING_DELTA_minTrailingBelowDelta': 10,
#  'TRAILING_DELTA_maxTrailingBelowDelta': 2000,
#  'PERCENT_PRICE_BY_SIDE_bidMultiplierUp': '5',
#  'PERCENT_PRICE_BY_SIDE_bidMultiplierDown': '0.2',
#  'PERCENT_PRICE_BY_SIDE_askMultiplierUp': '5',
#  'PERCENT_PRICE_BY_SIDE_askMultiplierDown': '0.2',
#  'PERCENT_PRICE_BY_SIDE_avgPriceMins': 5,
#  'MAX_NUM_ORDERS_maxNumOrders': 200,
#  'MAX_NUM_ALGO_ORDERS_maxNumAlgoOrders': 5}

# %%
ex.fee('BTCUSDT')
# Out:
# makerCommission    0.001
# takerCommission    0.001
# Name: BTCUSDT, dtype: float64

# %%
ex.coin('BTC')
# Out:
# depositAllEnable         True
# withdrawAllEnable        True
# name                  Bitcoin
# free                 0.000044
# locked                      0
# freeze                      0
# withdrawing                 0
# ipoing                      0
# ipoable                     0
# storage                     0
# isLegalMoney            False
# trading                  True
# Name: BTC, dtype: object

# %% [markdown]
# ### Info about Binance blockchain networks for any coin

# %%
ex.network('BTC')
# Out:
#         network  withdrawIntegerMultiple  isDefault  depositEnable  withdrawEnable depositDesc                                       withdrawDesc                                        specialTips                                specialWithdrawTips  \
# coin
# BTC   SEGWITBTC             1.000000e-08      False           True           False              Withdrawal for this token is not supported, pl...
# BTC         BTC             1.000000e-08       True           True            True
# BTC         BSC             1.000000e-08      False           True            True                                                                                                                    The network you have selected is BSC. Please e...
# BTC         ETH             1.000000e-08      False           True            True                                                                                                                    You are withdrawing Binance Wrapped BTC (BBTC)...
# BTC         BNB             1.000000e-08      False           True            True                                                                 Please enter both MEMO and Address data, which...                                                NaN
#
#                          name  ...   withdrawMax minConfirm unLockConfirm sameAddress  estimatedArrivalTime   busy                            country                   contractAddressUrl                             contractAddress  depositDust
# coin                           ...
# BTC               BTC(SegWit)  ...  1.000000e+10          1             2       False                     5  False                                NaN                                  NaN                                         NaN          NaN
# BTC                   Bitcoin  ...  7.500000e+03          1             2       False                    60  False  AE,BINANCE_BAHRAIN_BSC,custody,KZ                                  NaN                                         NaN          NaN
# BTC   BNB Smart Chain (BEP20)  ...  1.000000e+10         15             0       False                     5  False  AE,BINANCE_BAHRAIN_BSC,custody,KZ           https://bscscan.com/token/  0x7130d2a12b9bcbfae4f2634d864a1ee1ce3ead9c          NaN
# BTC          Ethereum (ERC20)  ...  1.000000e+10         12             0       False                     5  False  AE,BINANCE_BAHRAIN_BSC,custody,KZ          https://etherscan.io/token/  0x9be89d2a4cd102d8fecc6bf9da793be995c22541          NaN
# BTC   BNB Beacon Chain (BEP2)  ...  1.000000e+10          1             0        True                     5  False          AE,BINANCE_BAHRAIN_BSC,KZ  https://binance.mintscan.io/assets/                                    BTCB-1DE      0.00001
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Filter symbols with a coin as base or quote or both.

# %%
l = ex.get_symbols('BTC', base=False, quote=True)
l[:15]
# Out:
# ['ETHBTC',
#  'LTCBTC',
#  'BNBBTC',
#  'NEOBTC',
#  'BCCBTC',
#  'GASBTC',
#  'HSRBTC',
#  'MCOBTC',
#  'WTCBTC',
#  'LRCBTC',
#  'QTUMBTC',
#  'YOYOBTC',
#  'OMGBTC',
#  'ZRXBTC',
#  'STRATBTC']

# %% [markdown]
# ## Other method to show the symbols dataframe

# %%
ex.get_df()
# Out:
#            status baseAsset  baseAssetPrecision quoteAsset  quotePrecision  quoteAssetPrecision  baseCommissionPrecision  quoteCommissionPrecision                                         orderTypes  icebergAllowed  ...  isSpotTradingAllowed  \
# symbol                                                                                                                                                                                                                 ...
# ETHBTC    TRADING       ETH                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# LTCBTC    TRADING       LTC                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# BNBBTC    TRADING       BNB                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# NEOBTC    TRADING       NEO                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# QTUMETH   TRADING      QTUM                   8        ETH               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# ...           ...       ...                 ...        ...             ...                  ...                      ...                       ...                                                ...             ...  ...                   ...
# SOLTUSD   TRADING       SOL                   8       TUSD               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# SSVTUSD   TRADING       SSV                   8       TUSD               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# RDNTBTC   TRADING      RDNT                   8        BTC               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# RDNTUSDT  TRADING      RDNT                   8       USDT               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
# RDNTTUSD  TRADING      RDNT                   8       TUSD               8                    8                        8                         8  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True  ...                  True
#
#           isMarginTradingAllowed                                            filters  defaultSelfTradePreventionMode                  allowedSelfTradePreventionModes  SPOT MARGIN TRD_GRP_004 TRD_GRP_005  TRD_GRP_006
# symbol
# ETHBTC                      True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# LTCBTC                      True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# BNBBTC                      True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True        True        True         True
# NEOBTC                      True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True       False       False        False
# QTUMETH                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# ...                          ...                                                ...                             ...                                              ...   ...    ...         ...         ...          ...
# SOLTUSD                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True       False       False        False
# SSVTUSD                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# RDNTBTC                    False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
# RDNTUSDT                    True  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True   True       False       False        False
# RDNTTUSD                   False  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...                            NONE  [NONE, EXPIRE_TAKER, EXPIRE_MAKER, EXPIRE_BOTH]  True  False       False       False        False
#
# [2183 rows x 24 columns]

# %% [markdown]
# ## Order types supported by symbols

# %%
ex.get_order_types()
# Out:
#           LIMIT  LIMIT_MAKER  MARKET  STOP_LOSS_LIMIT  TAKE_PROFIT_LIMIT
# symbol
# ETHBTC     True         True    True             True               True
# LTCBTC     True         True    True             True               True
# BNBBTC     True         True    True             True               True
# NEOBTC     True         True    True             True               True
# QTUMETH    True         True    True             True               True
# ...         ...          ...     ...              ...                ...
# SOLTUSD    True         True    True             True               True
# SSVTUSD    True         True    True             True               True
# RDNTBTC    True         True    True             True               True
# RDNTUSDT   True         True    True             True               True
# RDNTTUSD   True         True    True             True               True
#
# [2183 rows x 5 columns]

# %%
# more fast method
ex.order_types
# Out:
#           LIMIT  LIMIT_MAKER  MARKET  STOP_LOSS_LIMIT  TAKE_PROFIT_LIMIT
# symbol
# ETHBTC     True         True    True             True               True
# LTCBTC     True         True    True             True               True
# BNBBTC     True         True    True             True               True
# NEOBTC     True         True    True             True               True
# QTUMETH    True         True    True             True               True
# ...         ...          ...     ...              ...                ...
# SOLTUSD    True         True    True             True               True
# SSVTUSD    True         True    True             True               True
# RDNTBTC    True         True    True             True               True
# RDNTUSDT   True         True    True             True               True
# RDNTTUSD   True         True    True             True               True
#
# [2183 rows x 5 columns]

# %% [markdown]
# # Top gainers of the last 24 hours can be requested from exchange handler

# %%
from secret import api_key, api_secret
top = handlers.exchange.get_top_gainers(decimal_mode=False, api_key=api_key, api_secret=api_secret)
# this can take a while
top
# Out:
#           priceChangePercent        volume  BUSD_value   BUSD_volume
# symbol
# AGLDUSDT              23.645  2.203415e+07    0.502000  1.106114e+07
# AGLDBUSD              23.342  9.635576e+06    0.502000  4.837059e+06
# PERLUSDT              22.649  1.578952e+08    0.032224  5.088046e+06
# AGLDBTC               22.176  1.752954e+06    0.502000  8.799827e+05
# STGUSDT               20.438  6.501154e+07    0.868600  5.646902e+07
# ...                      ...           ...         ...           ...
# IOTXBUSD              -4.896  4.474838e+07    0.029720  1.329922e+06
# MOBBTC                -4.995  3.356950e+05    1.499000  5.032068e+05
# IOTXUSDT              -5.267  3.382851e+08    0.029720  1.005383e+07
# IOTXBTC               -5.405  9.195948e+06    0.029720  2.733036e+05
# IOTXETH               -8.963  2.508357e+06    0.029720  7.454837e+04
#
# [1171 rows x 4 columns]

# %%
top.sort_values('BUSD_volume')
# Out:
#           priceChangePercent        volume   BUSD_value   BUSD_volume
# symbol
# ARPABNB                2.443  2.491500e+04      0.04215  1.050167e+03
# KP3RBNB               -0.117  2.268000e+01     80.18000  1.818482e+03
# XVSBNB                 1.190  4.410700e+02      4.78000  2.108315e+03
# FUNBNB                -2.476  2.569580e+05      0.00827  2.125024e+03
# ALICEBNB               1.071  1.401321e+03      1.63300  2.288357e+03
# ...                      ...           ...          ...           ...
# DOGEUSDT              -2.195  5.235360e+09      0.09669  5.062070e+08
# BTCTUSD                1.260  3.006250e+04  28530.66000  8.577030e+08
# ETHUSDT                4.633  6.701971e+05   1910.74000  1.280572e+09
# BTCUSDT                1.274  5.521673e+04  28530.66000  1.575370e+09
# BDOTDOT                0.516  5.560672e+03          NaN           NaN
#
# [1171 rows x 4 columns]

# %% [markdown]
# # Thank you

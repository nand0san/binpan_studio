# %% [markdown]
# # Reversal Chart from Atomic Trades
#
# Reversal candles are constructed from atomic (tick-level) trades instead of fixed time intervals. A new candle forms when the price reverses by a specified amount, making them useful for filtering out noise and focusing on significant price movements.
#
# Two key parameters control candle formation:
# - **min_height**: Minimum candle body height (in price ticks) required to close a candle.
# - **min_reversal**: Minimum reversal distance (in price ticks) from the high/low to trigger a new candle.
#
# This notebook demonstrates how to:
# 1. Fetch atomic trades for a symbol
# 2. Build reversal candles from those trades
# 3. Plot the resulting reversal candlestick chart

# %%
import binpan
binpan.__version__
# Out:
# '0.8.14'

# %%
# !python -V
# Out:
# Python 3.11.2

# %% [markdown]
# ## Create Symbol Object
#
# Create a `Symbol` object for the LTCBTC trading pair with 5-minute candles. The `hours=5` parameter fetches data for the last 5 hours.

# %%
ltc = binpan.Symbol(symbol='ltcbtc',
                    tick_interval='5m',
                    time_zone='Europe/Madrid',
                    hours=5)
# Out:
# 2026-03-04	 22:11:22     INFO get_candles_by_time_stamps -> symbol=LTCBTC tick_interval=5m start=2026-03-04 17:09:00 end=2026-03-04 22:05:59 limit=59
# 2026-03-04	 22:11:23     INFO Rate limits obtenidos de Binance API

# %% [markdown]
# ## Fetch Atomic Trades
#
# Fetch the individual (tick-level) trades for the time period covered by the Symbol object.

# %%
ltc.get_atomic_trades()
# Out:
# 2026-03-04	 22:11:24     INFO Obteniendo atomic trades de LTCBTC por tiempo: 2026-03-04 16:10:00.000000 -> 2026-03-04 21:00:00.000000
# Requesting atomic trades between 2026-03-04 17:10:00 and 2026-03-04 22:00:00
# 2026-03-04	 22:11:24     INFO Rango de IDs atómicos descubierto para LTCBTC: 106786281 -> 106788170 (estimado 1890 trades)
# 2026-03-04	 22:11:26     INFO Peticiones API atomic trades LTCBTC: 1 (ID actual: 106787281)
# 2026-03-04	 22:11:27     INFO Peticiones API atomic trades LTCBTC: 2 (ID actual: 106788281)
# 2026-03-04	 22:11:27     INFO Atomic trades LTCBTC: 2 peticiones, 2000 trades obtenidos
#                        Trade Id     Price  Quantity  Quote quantity                 Date      Timestamp  Buyer was maker  Best price match
# LTCBTC Europe/Madrid
# 0                     106786281  0.000777     1.827        0.001420  2026-03-04 17:11:04  1772640664560             True              True
# 1                     106786282  0.000778     0.397        0.000309  2026-03-04 17:11:20  1772640680042            False              True
# 2                     106786283  0.000778     0.380        0.000296  2026-03-04 17:11:20  1772640680042            False              True
# 3                     106786284  0.000778     0.193        0.000150  2026-03-04 17:11:21  1772640681027            False              True
# 4                     106786285  0.000778     0.232        0.000180  2026-03-04 17:11:52  1772640712276            False              True
# ...                         ...       ...       ...             ...                  ...            ...              ...               ...
# 1885                  106788166  0.000783     1.044        0.000817  2026-03-04 21:59:52  1772657992890            False              True
# 1886                  106788167  0.000784     0.236        0.000185  2026-03-04 21:59:55  1772657995303            False              True
# 1887                  106788168  0.000784     0.288        0.000226  2026-03-04 21:59:56  1772657996984            False              True
# 1888                  106788169  0.000784     0.342        0.000268  2026-03-04 21:59:57  1772657997064            False              True
# 1889                  106788170  0.000784     0.137        0.000107  2026-03-04 21:59:59  1772657999651            False              True
#
# [1890 rows x 8 columns]

# %%
# Verify that Trade IDs are consecutive (no missing trades)
assert len(ltc.atomic_trades['Trade Id'].diff().value_counts()) == 1

# %% [markdown]
# ## Build Reversal Candles
#
# Convert the atomic trades into reversal candles. The default parameters are `min_height=7` and `min_reversal=4`.

# %%
# Build reversal candles from the atomic trade data
ltc.get_reversal_atomic_candles()
# Out:
#                                       Open      High       Low     Close  Quantity      Timestamp
# Timestamp
# 2026-03-04 17:11:04.560000+01:00  0.000777  0.000784  0.000772  0.000784  4799.128  1772640664560

# %% [markdown]
# ## Plot Reversal Candles
#
# Plot the reversal candlestick chart. Here `min_height=10` (larger than default) will recompute the reversal candles.

# %%
ltc.plot_reversal(min_height=10, min_reversal=4, candles_ta_height_ratio=0.9, from_atomic=True)
# Out:
# 'C:\\Users\\ffad\\Pycharm_Projects\\binpan_studio\\last_plot.png'

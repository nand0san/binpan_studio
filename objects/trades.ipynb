# %%
from trades import Trades

# %%
a = Trades()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a = Trades()
#
# TypeError: Trades.__init__() missing 3 required positional arguments: 'start', 'end', and 'trades'
